# %%
import sys
import os
import pandas as pd
import requests

# %%
# all genes in Allen Brain Atlas... by default, this will only return the first 50 rows of the query
all_genes_query = "http://api.brain-map.org/api/v2/data/Gene/query.json"
all_genes_response = requests.get(all_genes_query).json()

# put the results into a pandas dataframe
all_genes = pd.DataFrame(all_genes_response['msg'])
all_genes.head()
# Out:
#   acronym                              alias_tags  chromosome_id ensembl_id  \
# 0    A1BG      A1B ABG DKFZp686F0970 GAB HYST2477             12       None
# 1     A2M  A2MD CPAMD5 DKFZp779B086 FWP007 S863-7              5       None
# 2   A2MP1                                    A2MP              5       None
# 3    NAT1                    AAC1 MNAT NAT-1 NATI             27       None
# 4    NAT2                         AAC2 NAT-2 PNAT             27       None
#
#    entrez_id  genomic_reference_update_id  homologene_id  id  \
# 0          1                    491928275        11167.0   2
# 1          2                    491928275        37248.0   3
# 2          3                    491928275            NaN   4
# 3          9                    491928275        37329.0   6
# 4         10                    491928275       115468.0   7
#
#   legacy_ensembl_gene_id                                               name  \
# 0                   None                             alpha-1-B glycoprotein
# 1                   None                              alpha-2-macroglobulin
# 2                   None                 alpha-2-macroglobulin pseudogene 1
# 3                   None  N-acetyltransferase 1 (arylamine N-acetyltrans...
# 4                   None  N-acetyltransferase 2 (arylamine N-acetyltrans...
#
#    organism_id                                      original_name  \
# 0            1                             alpha-1-B glycoprotein
# 1            1                              alpha-2-macroglobulin
# 2            1                 alpha-2-macroglobulin pseudogene 1
# 3            1  N-acetyltransferase 1 (arylamine N-acetyltrans...
# 4            1  N-acetyltransferase 2 (arylamine N-acetyltrans...
#
#   original_symbol reference_genome_id  sphinx_id version_status
# 0            A1BG                None     131297      no change
# 1             A2M                None     109391      no change
# 2           A2MP1                None     131617      no change
# 3            NAT1                None     110027      no change
# 4            NAT2                None     110308      no change

# %%
# all genes in developmental mouse: there are 2107
dev_mouse_criteria = "criteria=model::Gene,rma::criteria,products[abbreviation$eq'DevMouse']"
all_rows = "num_rows=all"
dev_mouse_genes_query = all_genes_query + "?" + dev_mouse_criteria + "&" + all_rows
dev_mouse_genes_response = requests.get(dev_mouse_genes_query).json()

# put the results into a pandas dataframe
dev_mouse_genes = pd.DataFrame(dev_mouse_genes_response['msg'])

print(dev_mouse_genes.shape)
dev_mouse_genes.head()
# Out:
# (2107, 16)
#   acronym               alias_tags  chromosome_id ensembl_id  entrez_id  \
# 0  Slc1a6                    EAAT4           35.0       None    20513.0
# 1    Lhx3  Lim3 mLim-3 mLIM3 P-LIM           47.0       None    16871.0
# 2    Dlx2     AW121999 Dlx-2 Tes-1           47.0       None    13392.0
# 3   Ncam2        Ncam-2 Ocam RNCAM           42.0       None    17968.0
# 4  Hcrtr1           MGC141357 Ox1r           49.0       None   230777.0
#
#    genomic_reference_update_id  homologene_id     id legacy_ensembl_gene_id  \
# 0                  491928275.0        21055.0  20275                   None
# 1                  491928275.0         7814.0  16642                   None
# 2                  491928275.0         3244.0  13171                   None
# 3                  491928275.0         3336.0  17735                   None
# 4                  491928275.0        37492.0  87114                   None
#
#                                                 name  organism_id  \
# 0  solute carrier family 1 (high affinity asparta...            2
# 1                             LIM homeobox protein 3            2
# 2                             distal-less homeobox 2            2
# 3                    neural cell adhesion molecule 2            2
# 4                     hypocretin (orexin) receptor 1            2
#
#                                        original_name original_symbol  \
# 0  solute carrier family 1 (high affinity asparta...          Slc1a6
# 1                             LIM homeobox protein 3            Lhx3
# 2                             distal-less homeobox 2            Dlx2
# 3                    neural cell adhesion molecule 2           Ncam2
# 4                     hypocretin (orexin) receptor 1          Hcrtr1
#
#   reference_genome_id  sphinx_id version_status
# 0                None     102670      no change
# 1                None      91840      no change
# 2                None      92911      no change
# 3                None      89989      no change
# 4                None      99831      no change

# %%
# our genes of interest
genes_of_interest = ['Robo2', 'Cdh5', 'Bmpr2']
our_genes = dev_mouse_genes[dev_mouse_genes.acronym.isin(genes_of_interest)]
our_genes.head()
# Out:
#      acronym                                         alias_tags  \
# 851    Bmpr2  2610024H22Rik AL117858 AW546137 BB189135 BMP-2...
# 1111   Robo2  2600013A04Rik 9430089E08Rik BB097918 D230004I2...
# 1447    Cdh5  7B4 AA408225 Cd144 CD144 Vec VEC VEcad VE-Cad ...
#
#       chromosome_id ensembl_id  entrez_id  genomic_reference_update_id  \
# 851            34.0       None    12168.0                  491928275.0
# 1111           42.0       None   268902.0                  491928275.0
# 1447           53.0       None    12562.0                  491928275.0
#
#       homologene_id     id legacy_ensembl_gene_id  \
# 851           929.0  11954                   None
# 1111        43188.0  92611                   None
# 1447         1359.0  12347                   None
#
#                                                    name  organism_id  \
# 851   bone morphogenetic protein receptor, type II (...            2
# 1111                  roundabout homolog 2 (Drosophila)            2
# 1447                                         cadherin 5            2
#
#                                           original_name original_symbol  \
# 851   bone morphogenic protein receptor, type II (se...           Bmpr2
# 1111                  roundabout homolog 2 (Drosophila)           Robo2
# 1447                                         cadherin 5            Cdh5
#
#      reference_genome_id  sphinx_id version_status
# 851                 None     358483        updated
# 1111                None     103280      no change
# 1447                None     101182      no change

# %%
# the "id" column gives the id of the gene
our_gene_ids = our_genes.id.values.tolist()
our_gene_ids
# Out:
# [11954, 92611, 12347]

# %%
# all experiments (section data sets) in developmental mouse 
all_data_query = "http://api.brain-map.org/api/v2/data/query.json"

# criteria to get experimental data from developmental mouse
dev_mouse_criteria = "criteria=model::SectionDataSet,rma::criteria,products[abbreviation$eq'DevMouse']"
gene_query_by_id = lambda id: "genes[id$eq'" + str(id) + "']"
all_rows = "num_rows=all"

experiment_queries = {id:all_data_query + "?" + dev_mouse_criteria + ',' + gene_query_by_id(id) + "&" + all_rows for id in our_gene_ids}
experiment_queries
# Out:
# {11954: "http://api.brain-map.org/api/v2/data/query.json?criteria=model::SectionDataSet,rma::criteria,products[abbreviation$eq'DevMouse'],genes[id$eq'11954']&num_rows=all",
#  12347: "http://api.brain-map.org/api/v2/data/query.json?criteria=model::SectionDataSet,rma::criteria,products[abbreviation$eq'DevMouse'],genes[id$eq'12347']&num_rows=all",
#  92611: "http://api.brain-map.org/api/v2/data/query.json?criteria=model::SectionDataSet,rma::criteria,products[abbreviation$eq'DevMouse'],genes[id$eq'92611']&num_rows=all"}

# %%
# collect all the experiment data pertaining to the 3 proteins into a pandas df
our_experiments = None
for gene_id, query in experiment_queries.items():
    print(query)
    query_response = requests.get(query).json()
    query_df = pd.DataFrame(query_response['msg'])
    query_df['gene_id'] = gene_id
    if our_experiments is None:
        our_experiments = query_df
    else:
        our_experiments = pd.concat([our_experiments, query_df])

our_experiments
# Out:
# http://api.brain-map.org/api/v2/data/query.json?criteria=model::SectionDataSet,rma::criteria,products[abbreviation$eq'DevMouse'],genes[id$eq'11954']&num_rows=all
# http://api.brain-map.org/api/v2/data/query.json?criteria=model::SectionDataSet,rma::criteria,products[abbreviation$eq'DevMouse'],genes[id$eq'92611']&num_rows=all
# http://api.brain-map.org/api/v2/data/query.json?criteria=model::SectionDataSet,rma::criteria,products[abbreviation$eq'DevMouse'],genes[id$eq'12347']&num_rows=all
#   blue_channel  delegate  expression  failed  failed_facet green_channel  \
# 0         None      True        True   False     734881840          None
# 1         None      True        True   False     734881840          None
# 2         None      True        True   False     734881840          None
# 3         None      True        True   False     734881840          None
# 4         None      True        True   False     734881840          None
# 5         None      True        True   False     734881840          None
# 6         None      True        True   False     734881840          None
# 7         None      True        True   False     734881840          None
# 0         None      True        True   False     734881840          None
# 1         None     False        True   False     734881840          None
# 2         None      True        True   False     734881840          None
# 3         None      True        True   False     734881840          None
# 4         None      True        True   False     734881840          None
# 5         None      True        True   False     734881840          None
# 6         None      True        True   False     734881840          None
# 7         None      True        True   False     734881840          None
# 8         None      True        True   False     734881840          None
# 0         None      True        True   False     734881840          None
# 1         None      True        True   False     734881840          None
# 2         None      True        True   False     734881840          None
# 3         None      True        True   False     734881840          None
# 4         None      True        True   False     734881840          None
# 5         None      True        True   False     734881840          None
# 6         None      True        True   False     734881840          None
# 7         None      True        True   False     734881840          None
# 8         None      True        True   False     734881840          None
# 9         None      True        True   False     734881840          None
#
#           id  name  plane_of_section_id               qc_date red_channel  \
# 0  100046444  None                    2  2009-07-28T16:18:33Z        None
# 1  100042306  None                    2  2009-02-18T14:28:00Z        None
# 2   69529382  None                    2  2009-05-02T22:47:10Z        None
# 3  100057140  None                    2  2009-05-04T16:12:12Z        None
# 4  100057296  None                    2  2009-05-06T15:44:29Z        None
# 5  100046631  None                    2  2009-06-23T09:52:00Z        None
# 6  100042432  None                    2  2009-02-05T13:43:02Z        None
# 7  100081744  None                    2  2009-10-09T14:34:30Z        None
# 0  100047274  None                    2  2009-07-30T11:51:16Z        None
# 1   75080998  None                    1  2009-05-02T23:06:21Z        None
# 2  100045469  None                    2  2009-02-12T11:00:41Z        None
# 3  100046870  None                    2  2009-07-20T10:13:56Z        None
# 4  100072173  None                    2  2009-06-11T09:45:04Z        None
# 5  100047596  None                    2  2009-06-23T14:34:42Z        None
# 6  100071976  None                    2  2009-09-21T09:29:34Z        None
# 7   71281319  None                    2  2009-05-02T22:56:30Z        None
# 8  100045355  None                    2  2009-06-01T10:57:49Z        None
# 0   77931975  None                    2  2009-05-02T22:33:29Z        None
# 1  100058500  None                    2  2009-06-19T09:11:16Z        None
# 2  100078477  None                    2  2009-10-06T11:29:56Z        None
# 3  100084794  None                    2  2010-02-06T01:34:53Z        None
# 4  100058480  None                    2  2009-07-16T16:59:27Z        None
# 5  100082796  None                    2  2010-01-04T18:35:41Z        None
# 6  100056407  None                    2  2009-05-05T15:28:36Z        None
# 7  100056766  None                    2  2009-07-22T11:39:06Z        None
# 8  100072907  None                    2  2009-08-19T11:13:06Z        None
# 9  100056389  None                    2  2009-06-05T13:33:05Z        None
#
#    reference_space_id rnaseq_design_id  section_thickness  specimen_id  \
# 0                   3             None               20.0         4908
# 1                   8             None               25.0         4797
# 2                  10             None               25.0     69486038
# 3                   5             None               20.0         6226
# 4                   6             None               20.0         6403
# 5                   2             None               20.0         4949
# 6                   7             None               25.0         4860
# 7                   1             None               20.0       701571
# 0                   3             None               20.0         5384
# 1                   9             None               25.0     74899344
# 2                   8             None               25.0         4879
# 3                   1             None               20.0         5219
# 4                   6             None               20.0         6758
# 5                   2             None               20.0         5066
# 6                   5             None               20.0         6732
# 7                  10             None               25.0     71121382
# 8                   7             None               25.0         4936
# 0                  10             None               25.0     77599077
# 1                   2             None               20.0         5749
# 2                   6             None               20.0       701459
# 3                  10             None               25.0       703034
# 4                   3             None               20.0         6135
# 5                  10             None               25.0         6997
# 6                   8             None               25.0         5448
# 7                   1             None               20.0         6204
# 8                   5             None               20.0         7039
# 9                   7             None               25.0         5332
#
#    sphinx_id                                  storage_directory  weight  \
# 0     148630  /external/devmouse/prod165/image_series_100046...    5200
# 1      83381  /external/devmouse/prod165/image_series_100042...    5200
# 2      34806  /external/aibssan/production32/prod330/image_s...    5470
# 3      43380  /external/devmouse/prod170/image_series_100057...    5200
# 4      58993  /external/devmouse/prod170/image_series_100057...    5200
# 5      77369  /external/devmouse/prod181/image_series_100046...    5200
# 6      55775  /external/devmouse/prod171/image_series_100042...    5200
# 7      36776  /external/devmouse/prod216/image_series_100081...    5200
# 0      32889  /external/devmouse/prod167/image_series_100047...    5200
# 1      18597  /external/aibssan/production32/prod342/image_s...    5470
# 2      58428  /external/devmouse/prod165/image_series_100045...    5200
# 3     151872  /external/devmouse/prod167/image_series_100046...    5200
# 4     102851  /external/devmouse/prod181/image_series_100072...    5200
# 5      81485  /external/devmouse/prod166/image_series_100047...    5200
# 6     159891  /external/devmouse/prod181/image_series_100071...    5200
# 7     110758  /external/aibssan/production32/prod337/image_s...    5470
# 8     154680  /external/devmouse/prod166/image_series_100045...    5200
# 0     143480  /external/aibssan/production32/prod344/image_s...    5470
# 1      39568  /external/devmouse/prod172/image_series_100058...    5200
# 2      53398  /external/devmouse/prod217/image_series_100078...    5200
# 3     118638  /external/devmouse/prod218/image_series_100084...    5200
# 4     133938  /external/devmouse/prod169/image_series_100058...    5200
# 5     106346  /external/devmouse/prod218/image_series_100082...    5200
# 6      52189  /external/devmouse/prod168/image_series_100056...    5200
# 7     119322  /external/devmouse/prod169/image_series_100056...    5200
# 8     122502  /external/devmouse/prod172/image_series_100072...    5200
# 9      89887  /external/devmouse/prod167/image_series_100056...    5200
#
#    gene_id
# 0    11954
# 1    11954
# 2    11954
# 3    11954
# 4    11954
# 5    11954
# 6    11954
# 7    11954
# 0    92611
# 1    92611
# 2    92611
# 3    92611
# 4    92611
# 5    92611
# 6    92611
# 7    92611
# 8    92611
# 0    12347
# 1    12347
# 2    12347
# 3    12347
# 4    12347
# 5    12347
# 6    12347
# 7    12347
# 8    12347
# 9    12347

# %%
# these are the experiment, or section data set, ids for all 
our_experiment_ids = our_experiments.id.values.tolist()
'experiment_ids:' + ','.join([str(i) for i in our_experiment_ids])
# Out:
# 'experiment_ids:\n100046444,100042306,69529382,100057140,100057296,100046631,100042432,100081744,100047274,75080998,100045469,100046870,100072173,100047596,100071976,71281319,100045355,77931975,100058500,100078477,100084794,100058480,100082796,100056407,100056766,100072907,100056389'

# %%
# let's view responses for section_data_set, given its id
experiment_criteria = "criteria=model::SectionImage"

# criteria to get experimental data from developmental mouse
experiment_query_by_id = lambda id: "[data_set_id$eq" + str(id) + "]"

experiment_query = all_data_query + "?" + experiment_criteria + ',rma::criteria,' +  experimet_query_by_id(100046444)
experiment_response = request.get(experiment_query)

# %%
sys.path.append(os.path.join(os.getcwd(), "src"))
from src.ecallen.ecallen import images as ecimg

all_image_ids = ecimg.get_all_section_image_ids(100046444)
